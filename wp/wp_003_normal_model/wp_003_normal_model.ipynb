# %% [markdown]
# # Explore relationships to build a normal model

# %%
import psycopg2
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def get_connection(schema="proj001_lfb_0_0_1", host = "localhost"):
    
    conn = psycopg2.connect("dbname='proj001_lfb' user='postgres' "
                            "host=" + host )
    if schema:
        cur = conn.cursor()
        query = "SET search_path TO {}".format(schema)
        cur.execute(query)
        
    return conn

# %% [markdown]
# # Incident address

# %% [markdown]
# ## Eastings and Northings
# These should be unique within a postcode

# %%
conn = get_connection()
qry = ('select distinct easting_m, northing_m, count(distinct postcode_full) '
          'from proj001_lfb_0_0_1.l2_incidents '
          'group by  easting_m, northing_m '
          'having count(distinct postcode_full) >1 '
          'order by count(distinct postcode_full) desc ;')
#data = pd.read_sql(qry, conn).drop(['store_no','store_type'], axis=1)  
data = pd.read_sql(qry, conn)

# %%
data.head(10)
# Out:
#   easting_m northing_m  count
# 0    529625     180625     49
# 1    529125     180375     41
# 2    529125     180625     38
# 3    528875     180875     36
# 4    529125     181375     35
# 5    529125     181125     32
# 6    533750     181250     31
# 7    529625     180875     30
# 8    531625     181125     30
# 9    528875     181125     29

# %% [markdown]
# Inspect the 2 worst cases to see what is going on

# %%
qry = ("select incidentnumber_cln, postcode_full, easting_m, northing_m "
           "from proj001_lfb_0_0_1.l2_incidents "
            "where (easting_m = '529625' and northing_m = '180625') "
            "or (easting_m = '529125' and northing_m = '180375') ;")
#data = pd.read_sql(qry, conn).drop(['store_no','store_type'], axis=1)  
data = pd.read_sql(qry, conn)  
data.head(20)
# Out:
#    incidentnumber_cln postcode_full easting_m northing_m
# 0             3627091       W1S 4NG    529125     180375
# 1             8124091       W1B 5RR    529625     180625
# 2            10139091      SW1Y 6HB    529625     180625
# 3            10456091       W1S 4NN    529125     180375
# 4            12055091       W1S 4HA    529125     180375
# 5            12924091       W1J 0DU    529125     180375
# 6            14343091       W1D 6BA    529625     180625
# 7            17240091       W1S 4HP    529125     180375
# 8            17935091       W1J 8DL    529125     180375
# 9            19103091       W1S 4NG    529125     180375
# 10           23474091       W1B 5RR    529625     180625
# 11           23670091      SW1Y 4RF    529625     180625
# 12           27712091       W1J 0BD    529125     180375
# 13           27766091       W1S 4JL    529125     180375
# 14           28111091       W1J 8DZ    529125     180375
# 15           29342091      SW1Y 4SP    529625     180625
# 16           31291091       W1B 4EG    529625     180625
# 17              34092       W1J 7BU    529625     180625
# 18           32553091       W1B 5AA    529625     180625
# 19           34585091      SW1A 1PL    529125     180375

# %% [markdown]
# # Here's a particularly bad inconsistency

# %%
qry = ("select * "
           "from proj001_lfb_0_0_1.l2_incidents "
           "where incidentnumber_cln in ('29342091','31291091', '17935091' , '19103091') " )
#data = pd.read_sql(qry, conn).drop(['store_no','store_type'], axis=1)  
data = pd.read_sql(qry, conn)  
data
# Out:
#   incidentnumber_cln            dateofcall_cln incidentgroup  \
# 0           17935091 2009-01-31 15:00:28+00:00   False Alarm
# 1           19103091 2009-02-02 10:54:24+00:00   False Alarm
# 2           29342091 2009-02-20 03:14:25+00:00   False Alarm
# 3           31291091 2009-02-23 09:27:45+00:00          Fire
#
#          stopcodedescription specialservicetype propertycategory  \
# 0  False alarm - Good intent               None  Non Residential
# 1                        AFA               None  Non Residential
# 2                        AFA               None  Non Residential
# 3               Primary Fire               None  Non Residential
#
#             propertytype           addressqualifier postcode_full  \
# 0        Restaurant/cafe  Correct incident location       W1J 8DL
# 1  Purpose built office   Correct incident location       W1S 4NG
# 2  Purpose built office        Within same building      SW1Y 4SP
# 3           Single shop        Within same building       W1B 4EG
#
#   incgeo_boroughname incgeo_wardname incgeo_wardnamenew easting_m northing_m  \
# 0        WESTMINSTER     ST. JAMES'S        ST. JAMES'S    529125     180375
# 1        WESTMINSTER     ST. JAMES'S        ST. JAMES'S    529125     180375
# 2        WESTMINSTER     ST. JAMES'S        ST. JAMES'S    529625     180625
# 3        WESTMINSTER     ST. JAMES'S        ST. JAMES'S    529625     180625
#
#       frs incidentstationground  numstationswithpumpsattending  \
# 0  LONDON                  SOHO                              3
# 1  LONDON                  SOHO                              1
# 2  LONDON                  SOHO                              1
# 3  LONDON                  SOHO                              2
#
#    numpumpsattending
# 0                  3
# 1                  1
# 2                  1
# 3                  3

# %% [markdown]
# So while Eastings and Northings seem inaccurate within postcode, these postcodes seem to be adjacent. Is this just small location errors in the Eastings and Northings?

# %% [markdown]
# ## How many easting/northing combinations within a postcode?

# %%
qry = ("select distinct postcode_full,  easting_m, northing_m, count(*) "
           "from proj001_lfb_0_0_1.l2_incidents "
           "group by postcode_full,  easting_m, northing_m "
           "order by postcode_full, count(*) desc ;" )

data = pd.read_sql(qry, conn)  
data.head(20)
# Out:
#    postcode_full easting_m northing_m  count
# 0        AL1 3EA    514850     207450      1
# 1        AL2 1QY    518215     203627      1
# 2        BR1 1AE    540194     169201      4
# 3        BR1 1AE    540250     169250      1
# 4        BR1 1BQ    540299     169607      1
# 5        BR1 1BW    540381     168612      1
# 6        BR1 1BY    539955     169594      1
# 7        BR1 1DD    540364     169136      6
# 8        BR1 1DD    540350     169133      1
# 9        BR1 1DE    539934     169644      1
# 10       BR1 1DJ    540250     168750      1
# 11       BR1 1DN    540364     169136     21
# 12       BR1 1DN    540250     169250      3
# 13       BR1 1DP    540250     168750      2
# 14       BR1 1DP    540250     168250      1
# 15       BR1 1DS    540381     168612      3
# 16       BR1 1DS    540355     168677      2
# 17       BR1 1DU    540381     168612      1
# 18       BR1 1DW    540216     169154      3
# 19       BR1 1EA    540335     168834      2

# %% [markdown]
# So we will model post code as one entity and then easting/northing as the specific incident address

# %% [markdown]
# ## Quality of postcodes
# It seems postcode is not always complete. THere are many instances where `postcode_district` was completed but `postcode_full` was not

# %%
conn = get_connection()
qry = ("select distinct postcode_full, postcode_district "
           "from proj001_lfb_0_0_1.L1_LFB_Incident_data_from_January_2009_to_December_2012 "
           "order by postcode_full, postcode_district;" )
data = pd.read_sql(qry, conn)  

data[data['postcode_full'].isnull()]
# Out:
#       postcode_full postcode_district
# 71846          None               BR1
# 71847          None               BR2
# 71848          None               BR3
# 71849          None               BR4
# 71850          None               BR5
# 71851          None               BR6
# 71852          None               BR7
# 71853          None               BR8
# 71854          None              CM12
# 71855          None              CM13
# 71856          None              CM14
# 71857          None              CM15
# 71858          None              CM16
# 71859          None              CM18
# 71860          None               CR0
# 71861          None               CR2
# 71862          None               CR3
# 71863          None               CR4
# 71864          None               CR5
# 71865          None               CR6
# 71866          None               CR7
# 71867          None               CR8
# 71868          None               CR9
# 71869          None               DA1
# 71870          None              DA10
# 71871          None              DA14
# 71872          None              DA15
# 71873          None              DA16
# 71874          None              DA17
# 71875          None              DA18
# ...             ...               ...
# 72142          None               W1S
# 72143          None               W1T
# 72144          None               W1U
# 72145          None               W1W
# 72146          None               W1X
# 72147          None                W2
# 72148          None                W3
# 72149          None                W4
# 72150          None                W5
# 72151          None                W6
# 72152          None                W7
# 72153          None                W8
# 72154          None                W9
# 72155          None              WC1A
# 72156          None              WC1B
# 72157          None              WC1E
# 72158          None              WC1H
# 72159          None              WC1N
# 72160          None              WC1R
# 72161          None              WC1V
# 72162          None              WC1X
# 72163          None              WC2A
# 72164          None              WC2B
# 72165          None              WC2E
# 72166          None              WC2H
# 72167          None              WC2N
# 72168          None              WC2R
# 72169          None              WD19
# 72170          None              WD23
# 72171          None               WD3
#
# [326 rows x 2 columns]

# %% [markdown]
# ## Property
# Look into the fields that should be part of a property entity.

# %%
conn = get_connection()
qry = ("select distinct propertycategory, propertytype, addressqualifier "
           "from proj001_lfb_0_0_1.l2_incidents "
           "order by propertycategory, propertytype, addressqualifier;" )

data = pd.read_sql(qry, conn)  
data.head(20)
# Out:
#    propertycategory          propertytype  \
# 0          Aircraft        Freight plane
# 1          Aircraft        Freight plane
# 2          Aircraft        Freight plane
# 3          Aircraft        Freight plane
# 4          Aircraft           Helicopter
# 5          Aircraft           Helicopter
# 6          Aircraft       Light aircraft
# 7          Aircraft       Light aircraft
# 8          Aircraft       Light aircraft
# 9          Aircraft  Military helicopter
# 10         Aircraft        Other aircraft
# 11         Aircraft        Other aircraft
# 12         Aircraft        Other aircraft
# 13         Aircraft        Other aircraft
# 14         Aircraft      Passenger plane
# 15         Aircraft      Passenger plane
# 16         Aircraft      Passenger plane
# 17         Aircraft      Passenger plane
# 18         Aircraft      Passenger plane
# 19         Aircraft      Passenger plane
#
#                                    addressqualifier
# 0          In street remote from gazetteer location
# 1            Nearby address - no building in street
# 2   Nearby address - street not listed in gazetteer
# 3                  On land associated with building
# 4                         Correct incident location
# 5                  On land associated with building
# 6                         Correct incident location
# 7   Nearby address - street not listed in gazetteer
# 8                  On land associated with building
# 9      Open land/water - nearest gazetteer location
# 10            In street close to gazetteer location
# 11  Nearby address - street not listed in gazetteer
# 12                 On land associated with building
# 13     Open land/water - nearest gazetteer location
# 14                        Correct incident location
# 15            In street close to gazetteer location
# 16             In street outside gazetteer location
# 17         In street remote from gazetteer location
# 18           Nearby address - no building in street
# 19  Nearby address - street not listed in gazetteer

# %% [markdown]
# It seems like `addressqualifier` is less important

# %%
conn = get_connection()
qry = ("select distinct  addressqualifier "
           "from proj001_lfb_0_0_1.l2_incidents "
           "order by addressqualifier;" )

data = pd.read_sql(qry, conn)  
data
# Out:
#                                    addressqualifier
# 0                         Correct incident location
# 1             In street close to gazetteer location
# 2              In street outside gazetteer location
# 3          In street remote from gazetteer location
# 4            Nearby address - no building in street
# 5   Nearby address - street not listed in gazetteer
# 6                  On land associated with building
# 7                       On motorway / elevated road
# 8      Open land/water - nearest gazetteer location
# 9                     Railway land or rolling stock
# 10                             Within same building
